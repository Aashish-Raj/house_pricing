# %%
import pandas as pd
import numpy as  np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#  load data set
df=pd.read_csv("HousingData.csv")

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.rename(columns={"MEDV":"Price"},inplace=True)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90    NaN   36.2

# %%
#  sumarixze the data
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# find null value
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# Price       0
# dtype: int64

# %%
# find percenatge null value
df.isnull().mean()*100
# Out:
# CRIM       3.952569
# ZN         3.952569
# INDUS      3.952569
# CHAS       3.952569
# NOX        0.000000
# RM         0.000000
# AGE        3.952569
# DIS        0.000000
# RAD        0.000000
# TAX        0.000000
# PTRATIO    0.000000
# B          0.000000
# LSTAT      3.952569
# Price      0.000000
# dtype: float64

# %%
# fetch column that hav emissing value
nl_c=[]
for i in df.columns:
    if df[i].isnull().sum()>0:
        nl_c.append(i)

# %%
#  print column
nl_c
# Out:
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'AGE', 'LSTAT']

# %%
#  cheeck the distribution of null column data
df[nl_c].describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         AGE       LSTAT
# count  486.000000  486.000000  486.000000  486.000000  486.000000  486.000000
# mean     3.611874   11.211934   11.083992    0.069959   68.518519   12.715432
# std      8.720192   23.388876    6.835896    0.255340   27.999513    7.155871
# min      0.006320    0.000000    0.460000    0.000000    2.900000    1.730000
# 25%      0.081900    0.000000    5.190000    0.000000   45.175000    7.125000
# 50%      0.253715    0.000000    9.690000    0.000000   76.800000   11.430000
# 75%      3.560263   12.500000   18.100000    0.000000   93.975000   16.955000
# max     88.976200  100.000000   27.740000    1.000000  100.000000   37.970000

# %%
#  plot distri bution plot
for i,col in enumerate(nl_c):
    plt.subplot(3,2,1+i)
    sns.distplot(df[col])
    plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.4)
#     plt.title(col)
# Out:
# C:\Users\Aashish\AppData\Local\Temp\ipykernel_2104\1386613266.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# C:\Users\Aashish\AppData\Local\Temp\ipykernel_2104\1386613266.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# ...

# %%
#  plot box plot
sns.boxplot(df[nl_c])
# Out:
# <AxesSubplot: >

# %%
df[['INDUS','AGE',"CHAS"]].mean()
# Out:
# INDUS    11.083992
# AGE      68.518519
# CHAS      0.069959
# dtype: float64

# %%
df[['INDUS','AGE',"CHAS"]].median()
# Out:
# INDUS     9.69
# AGE      76.80
# CHAS      0.00
# dtype: float64

# %%
# fill missing value
df[['INDUS','AGE',"CHAS"]]=df[['INDUS','AGE',"CHAS"]].fillna(df.median())

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# Price       0
# dtype: int64

# %%
df.shape
# Out:
# (506, 14)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (447, 14)

# %%
#  check duplicated data
df.duplicated().sum()
# Out:
# 0

# %%
#  exploratory data analysis
#  correlation
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
# sns.pairplot(df)

# %%
sns.scatterplot(x=df["CRIM"],y=df["Price"])
# Out:
# <AxesSubplot: xlabel='CRIM', ylabel='Price'>

# %%
sns.scatterplot(x=df["RM"],y=df["Price"])
# Out:
# <AxesSubplot: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x=df["RM"],y=df["Price"])
# Out:
# <AxesSubplot: xlabel='RM', ylabel='Price'>

# %%
sns.regplot(x=df["LSTAT"],y=df["Price"])
# Out:
# <AxesSubplot: xlabel='LSTAT', ylabel='Price'>

# %%
sns.regplot(x=df["CHAS"],y=df["Price"])
# Out:
# <AxesSubplot: xlabel='CHAS', ylabel='Price'>

# %%
sns.regplot(x=df["PTRATIO"],y=df["Price"])
# Out:
# <AxesSubplot: xlabel='PTRATIO', ylabel='Price'>

# %%
#  divide in independent an dependent featurex=

x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 5  394.12   5.21

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 5    28.7
# Name: Price, dtype: float64

# %%
# train test split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (357, 13)

# %%
y_train.shape
# Out:
# (357,)

# %%
x_test.shape
# Out:
# (90, 13)

# %%
y_test.shape
# Out:
# (90,)

# %%
#  standarize the data set
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.3300922 , -0.49144511, -0.42558893, ...,  1.18872409,
#         -0.75275471, -0.13605021],
#        [-0.41460115,  0.00399684, -0.72971801, ...,  0.21761539,
#          0.43289019, -0.54542269],
#        [-0.42885448,  1.88667626, -1.19105391, ..., -1.30841255,
#          0.21094572, -1.16795118],
#        ...,
#        [ 0.66139425, -0.49144511,  1.03775679, ...,  0.81877792,
#          0.37883243,  0.63046445],
#        [-0.40894467, -0.49144511, -0.19785943, ...,  0.35634521,
#          0.43289019, -0.09087808],
#        [-0.3976292 , -0.49144511, -0.36388158, ...,  1.14248082,
#          0.37059191,  0.40883867]])

# %%
x_test
# Out:
# array([[-0.40966003, -0.49144511, -0.53724985, ...,  0.54131829,
#          0.43289019, -0.76987174],
#        [ 0.4923087 , -0.49144511,  1.03775679, ...,  0.81877792,
#         -2.86518254,  1.25158131],
#        [-0.39819046, -0.49144511,  1.59459216, ...,  1.28121063,
#          0.38026078,  0.64034586],
#        ...,
#        [-0.41195018,  0.49943879, -0.86782494, ...,  0.58756156,
#          0.41322283,  0.07004765],
#        [ 0.28241632, -0.49144511,  1.03775679, ...,  0.81877792,
#          0.38652357,  0.3283758 ],
#        [-0.32535279, -0.49144511, -0.42558893, ...,  1.18872409,
#         -0.59420725,  0.54435507]])

# %%
#  model trainig
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#  prinnt coefficients nd intercept
print(lr.coef_)
# Out:
# [-0.8468683   1.12843338 -0.13968078  0.80856745 -2.08736202  2.25715929
#   0.36288494 -2.92920098  2.8124812  -1.91548123 -1.95117831  0.84404516
#  -4.28901137]

# %%
print(lr.intercept_)
# Out:
# 22.461344537815137

# %%
#  parameters for trai model
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
pred=lr.predict(x_test)

# %%
pred
# Out:
# array([25.02622532, 13.7671645 , 14.83159335, 18.92046739, 25.91028579,
#        18.55818072,  9.22599908, 24.70147176, 16.41926679, 13.99924292,
#        22.31771859, 36.26914223,  6.67968064, 21.41262252, 18.28856554,
#        18.81475604, 28.36661333, 35.43851212, 12.31521958, 26.12810214,
#        32.74608298, 18.61579294, 35.33801814, 24.60329084, 12.70521532,
#        20.95437303, 22.82703973, 30.88221816, 32.69098769, 27.4943113 ,
#        24.08535088, 16.17991281, 23.1065629 ,  0.41589042, 13.96961124,
#        20.29438823, 18.74685541, 27.32898138, 12.56727438, 39.50778752,
#        38.71777451, 18.52492068, 15.06897309, 15.55440811, 42.1036917 ,
#        20.32178861, 22.77144004, 21.16374729, 25.35273457, 13.5178424 ,
#        18.7906679 , 22.41237417, 25.80603437, 16.51873523, 20.40586453,
#        11.36482535, 20.78561319, 24.61103992, 11.04367465, 30.24965857,
#        12.61989774, 25.09143681, 19.88845863, 21.68954257, 42.1780241 ,
# ...

# %%
#  plot scatter plot for the prediction
plt.scatter(y_test,pred)

# %%
#  residual
residual=y_test-pred

# %%
residual
# Out:
# 320   -1.226225
# 428   -2.767164
# 127    1.368407
# 442   -0.520467
# 74    -1.810286
#          ...
# 496    5.952245
# 435    0.683201
# 60     0.150987
# 486   -0.812470
# 25     0.144745
# Name: Price, Length: 90, dtype: float64

# %%
#  plot residual

sns.displot(residual,kind="kde")

# %%
plt.scatter(x=pred,y=residual)

# %%
#  performance metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print(mean_absolute_error(y_test,pred))
print(mean_squared_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 3.2305649017209204
# 19.471460240885254
# 4.412647758532881

# %%
#  r2 and adjusted r2

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,pred)

# %%
score
# Out:
# 0.7539226660640069

# %%
#  adjusted r2
1-(1-score)*(len(y_test-1))/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.7085926308652714

# %%
#  new data preediction

# %%
x_train[0].shape
# Out:
# (13,)

# %%
x_train[0].reshape(1,-1)
# Out:
# array([[-0.3300922 , -0.49144511, -0.42558893, -0.29172998, -0.14720443,
#         -1.14464196, -1.19088402, -0.01356287, -0.62841267, -0.58846859,
#          1.18872409, -0.75275471, -0.13605021]])

# %%
x_train[0].reshape(1,-1).shape
# Out:
# (1, 13)

# %%
lr.predict(x_train[0].reshape(1,-1))
# Out:
# array([16.32964454])

# %%
#  save the model for deployment

# %%
import pickle

# %%
pickle.dump(lr,open("regressionmdl.pkl","wb"))

# %%
pickle_model=pickle.load(open("regressionmdl.pkl","rb"))

# %%
#  reuse the model
pickle_model.predict(x_train[0].reshape(1,-1))
# Out:
# array([16.32964454])
